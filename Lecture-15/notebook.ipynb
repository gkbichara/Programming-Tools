# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')
df.head()
# Out:
#     id    name  age education        department
# 0  123    Luai   25        BA  computer science
# 1  331    Ziad   27       MBA              math
# 2  441    Taha   30        BA              math
# 3  221    Suha   26        BA         chemistry
# 4  336  Sandra   27       MBA  computer science

# %%
# values here is the average of the column that you selected (age in this case_)
df.pivot_table(index = 'department', columns = 'education', values = 'age')
# Out:
# education           BA   MBA   PhD
# department
# chemistry         26.0  31.0  33.0
# computer science  25.0  27.0   NaN
# economics         21.0  20.0  35.0
# math              30.0  27.0  29.0

# %%
# read data from file countries.csv
# keep columns 

df = pd.read_csv('countries.csv', sep = ';')
df = df.iloc[:, [0,4,6,7,8,10,13,14,15]]

# %%
# change column names to be lower case
df.columns = df.columns.str.lower()

# %%
# remove rows with missing values
df = df.dropna(axis = 0, how = 'any')

# %%
df
# Out:
#                       country  continent  population     area  coastline  \
# 0                 Afghanistan       Asia    33332025   652230          0
# 1                       Egypt     Africa    94666993  1001450       2450
# 2               Åland Islands     Europe       29013     1580          0
# 3                     Albania     Europe     3038594    28748        362
# 4                     Algeria     Africa    40263711  2381741        998
# ..                        ...        ...         ...      ...        ...
# 243         Wallis and Futuna    Oceania       15664      142        129
# 244          Christmas Island  Australia        2205      135        139
# 245            Western Sahara     Africa      587020   266000       1110
# 246  Central African Republic     Africa     5507257   622984          0
# 247                    Cyprus       Asia     1205575     9251        648
#
#     currency  birthrate  deathrate  life expectancy
# ...

# %%
# filter on population
df = df.loc[df.population > 20000000]

# %%
df.reset_index()
# Out:
#     index                           country      continent  population  \
# 0       0                       Afghanistan           Asia    33332025
# 1       1                             Egypt         Africa    94666993
# 2       4                           Algeria         Africa    40263711
# 3       7                            Angola         Africa    20172332
# 4      12                         Argentina  South America    43886748
# 5      16                          Ethiopia         Africa   102374044
# 6      17                         Australia      Australia    22992654
# 7      20                        Bangladesh           Asia   156186882
# 8      32                            Brazil  South America   205823665
# 9      39                             China           Asia  1373541278
# 10     44  Democratic Republic of the Congo         Africa    81331050
# 11     45                           Germany         Europe    80722792
# ...

# %%
del df['index']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/anaconda3/envs/projectenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 del df['index']
#
# ...

# %%
# add a boolean to those with a coastline
df['coastal'] = df['coastline'] > 0
df
# Out:
# /var/folders/kx/58cjbwzx5jjgn5w_sjz3qk0w0000gn/T/ipykernel_15444/3758491513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['coastal'] = df['coastline'] > 0
#                               country      continent  population      area  \
# 0                         Afghanistan           Asia    33332025    652230
# 1                               Egypt         Africa    94666993   1001450
# 4                             Algeria         Africa    40263711   2381741
# 7                              Angola         Africa    20172332   1246700
# 12                          Argentina  South America    43886748   2780400
# 16                           Ethiopia         Africa   102374044   1104300
# ...

# %%
# find the max and min of life expectancy for coastal and landlocked countries
df.groupby('coastal').agg(['min', 'max'])[['life expectancy']]
df[['life expectancy', 'coastal']].groupby('coastal').agg(['min', 'max'])
# Out:
#         life expectancy
#                     min   max
# coastal
# False              51.3  73.8
# True               53.3  85.0

# %%
# find how many coastal and landlocked countries there are in each continent

df.groupby(['continent', 'coastal']).size()
# Out:
# continent      coastal
# Africa         False       2
#                True       15
# Asia           False       3
#                True       20
# Australia      True        1
# Europe         True        9
# North America  True        3
# South America  True        5
# dtype: int64

# %%
# determine the average deathrate for each coastal and landlocked countries in continents

df[['coastal', 'continent', 'deathrate']].groupby(['continent', 'coastal']).mean(['deathrate'])
# Out:
#                        deathrate
# continent     coastal
# Africa        False     9.150000
#               True      8.293333
# Asia          False     8.233333
#               True      6.460000
# Australia     True      7.200000
# Europe        True     11.100000
# North America True      7.333333
# South America True      6.140000

# %%
# create a new column that measures population density
df['density'] = df['population'] / df['area']
# Out:
# /var/folders/kx/58cjbwzx5jjgn5w_sjz3qk0w0000gn/T/ipykernel_15444/1465260033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['density'] = df['population'] / df['area']

# %%
df.density.mean()
# Out:
# np.float64(142.1239784002992)

# %%
### Visualizations in Python

# %%
import matplotlib.pyplot as plt

# %%
x = [5,5,5,10,10,30,20,25,40]
plt.hist(x)
plt.show()

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x144f6b6a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x145de1180>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x144f68df0>],
#  'medians': [<matplotlib.lines.Line2D at 0x145de1a80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x145de0340>],
#  'means': []}

# %%
values = [2415, 1441, 1254, 15135, 13531, 3214, 1243]
Labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
plt.pie(values, labels = Labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x145d1f790>,
# ...
#  [Text(1.0784128951029421, 0.21685393165836572, 'A'),
#   Text(0.9571670208368209, 0.5420620759861041, 'B'),
#   Text(0.8147340732176267, 0.739059124791931, 'C'),
#   Text(-0.539504162389459, 0.9586111092431844, 'D'),
#   Text(-0.29711475971551154, -1.0591141673866864, 'E'),
#   Text(0.9815376027122156, -0.4965721845431509, 'F'),
#   Text(1.0942675210104953, -0.11215432431050341, 'G')])

# %%
x = ['a', 'b', 'c', 'd']
y = [1,2,3,4]

plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
# same thing but horizontally
plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
# can plot more than one, will be separated by color

x = [7,8,9,11]
y = [9,4,6,7]
k = [8,5,8,4]
m = [3,5,8,3]

plt.scatter(x, y)
plt.scatter(k, m)

# %%
# plotting

x = [7,8,9,11]
y = [9,4,6,7]
k = [8,5,8,4]
m = [3,5,8,3]

plt.plot(x, y, color = 'green', marker='o', markersize = 20)
# plt.plot(x, m, marker='^', markersize = 15, alpha = 0.3)
plt.plot(x, m,'r.--') # the string goes as follows: color, marker, type of line

# %%
# plot features
plt.figure(figsize = (4,3))

# plot both lines together
plt.plot(x, y, label  = 'data1')
plt.plot(x, k, label  = 'data2')

plt.legend(loc = 3) # loc determines where the legend is located

plt.title('Example plot')
plt.xlabel('time')
plt.ylabel('money')
plt.xlim(6, 20)
plt.ylim(0,10)

plt.xticks([6,9,12])
plt.yticks([0,4,8])

plt.text(10, 2, 'some text', color = 'blue', size = 14)
# Out:
# Text(10, 2, 'some text')

# %%
# Exercise
