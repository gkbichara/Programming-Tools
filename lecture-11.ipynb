# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
url = 'https://www.bbc.com/'

response = requests.get(url)
data = response.text

soup = BeautifulSoup(data)
text = soup.find_all('h2')

news = [t.text for t in soup.find_all('h2')]
# Out:
# ['Tate brothers arrive in US after Romania prosecutors lift travel ban',
#  'Why are the Tate brothers in the US?',
#  'Tate brothers arrive in US after Romania prosecutors lift travel ban',
#  'Why are the Tate brothers in the US?',
#  'Trump and Starmer giving news conference after White House meeting',
#  "Death of Hackman and wife 'suspicious enough' for investigation, police say",
#  "Gene Hackman's daughters and Clint Eastwood lead tributes to star",
#  "Man's brain turned to glass by hot Vesuvius ash cloud ",
#  'Katy Perry to head to space on Blue Origin all-women flight',
#  'Only from the BBC',
#  'Did a gay affair stir a 14th-Century royal crisis?',
#  'An expert guide to emotional control',
#  'More news',
#  'Trump says US will impose additional 10% tariff on China',
#  "'I need help': Freed from Myanmar's scam centres, thousands are now stranded",
#  'Thailand deports dozens of Uyghurs to China',
#  'Jailed Kurdish leader issues call to lay down arms',
#  'BBC Verify: Viral Donald Trump Jr audio highly likely AI fake',
#  'Must watch',
#  'Watch: Trump welcomes Starmer to the White House',
#  'When Chris O’Dowd met Beyoncé',
#  'Watch: Andrew Tate and brother Tristan arrive in US',
#  'Marvellous views of the moon captured by private lunar lander',
#  "Watch: Tough guy to eccentric grandad - a look back at Hackman's greatest roles",
#  'Watch: Drone lights up night rescue of teen trapped in a crevasse',
#  "The dos and don'ts for meetings with Trump",
#  'Aerial footage captures forest fire burning in northern Japan',
#  'Travel ',
#  'The quiet towns that sparked US independence',
#  'Culture',
#  "Gene Hackman: One of Hollywood's greatest 'tough guys'",
#  'Audio',
#  'Business Daily',
#  'The Documentary Podcast',
#  'In Our Time',
#  'The Infinite Monkey Cage',
#  'Witness History',
#  'World Business Report',
#  'The Global Story',
#  'Football Daily',
#  'US & Canada news',
#  "Three possible paths to freedom: What's next for the Menendez brothers?",
#  'Michelle Trachtenberg, Gossip Girl and Buffy actress, dies aged 39',
#  'Trump foreign aid freeze to stay for now, US Supreme Court chief rules',
#  'Trump administration unveils bird flu plan as egg prices soar',
#  'Israel-Gaza war',
#  'Stories of the hostages taken by Hamas from Israel',
#  'Who are Israeli hostages released and rescued from Gaza?',
#  'Protesters barred from disrupting degree ceremony',
#  "Israel's military publishes first report on 7 October 2023 failures",
#  'War in Ukraine',
#  'How much has the US given to Ukraine?',
#  'Ukraine and Lincolnshire sign farming agreement',
#  'Watch: Trump welcomes Starmer to the White House',
#  "'Did I say that?' - Trump asked about calling Zelensky a 'dictator'",
#  'Sport',
#  'Man City reported to European Commission over rule breaches - Tebas',
#  "Ireland's O'Mahony, Healy and Murray to retire",
#  'Premier League Darts - Dobey v Aspinall in Exeter',
#  "Premier League: Deflected Bowen effort doubles West Ham's lead over Leicester",
#  'Video',
#  'Raye: Resilience is key when pursuing career in music',
#  'Business',
#  'Trump says 25% tariffs on EU will be announced soon',
#  "Amazon joins quantum race with 'cat qubit' powered chip",
#  "Succession-like feud engulfs one of Singapore's richest families",
#  'Goldman Sachs pledges £1.5m to support apprentices',
#  'Tech',
#  'Crypto sleuths join hunt for $1.5bn stolen in biggest ever heist',
#  "Alexa relaunched with ambition to be 'your best digital friend'",
#  'Instagram may launch separate Reels app to take on TikTok - report',
#  "Amazon joins quantum race with 'cat qubit' powered chip",
#  'Science & health',
#  "Indian doctors remove teen's 'parasitic' twin in rare surgery",
#  'What your poo can reveal about your health',
#  'Cancer scans to be revolutionised by nuclear start-up',
#  "Cousin marriage: What new evidence tells us about children's ill health",
#  'Culture',
#  'The 1995 cult comedy that changed how teens dress and talk',
#  "'Taking your shirt off on the red carpet is different': Will Chalamet's wild campaign win him an Oscar?",
#  'Watch: Behind the scenes at the Oscars red carpet rollout',
#  "Pamela Anderson on missing out on Oscars, ditching makeup and 'innocence' of Baywatch",
#  'Discover more from the BBC',
#  'Tech Decoded',
#  'Download the BBC app',
#  'US Politics Unspun',
#  'Register for a BBC account',
#  'Subscribe to the Essential List',
#  'Sign up to News Briefing',
#  'Subscribe to Future Earth ',
#  'World of Business',
#  'Arts',
#  'A glimpse at Picasso and Pollock masterpieces kept in Tehran vault',
#  'Eight portraits found hidden inside masterpieces',
#  'The troubled history of the Sydney Opera House',
#  'The Lion King: How Mufasa was brought to life',
#  'Travel',
#  "A tiny island that's redefining travel to Thailand",
#  "Central Europe's new hop-on hop-off train",
#  "How Trump's new policies could change travel",
#  "A White Lotus actor's guide to Thailand",
#  'Earth',
#  'Half of UK homes need heat pump by 2040, government told',
#  'The perplexing history of the chameleon',
#  'Seven planets to be visible in night sky for last time until 2040',
#  'BP shuns renewables in return to oil and gas ',
#  'Future Planet',
#  'Which is worse for wildlife, wind farms or oil drilling?',
#  'The bugs transforming food waste into fertiliser',
#  "The rewilded golf courses turned into a nature 'microcosm'",
#  'The ex-fracking site tapped for underground heat',
#  'Follow BBC on:']
