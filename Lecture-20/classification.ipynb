# %%
import pandas as pd
# from sklearn.
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# determine X and Y

X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

# %%
# split data into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
# build and train model
from sklearn.neighbors import KNeighborsClassifier

# default num eighbors is 5
# recommended n is the square root is the square root of the number of instances in the training set
my_classifier  = KNeighborsClassifier(n_neighbors = 5)              # n_neighbors = round(X_train ** 0.5)
my_classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
# evaluate the mode

Y_predicted = my_classifier.predict(X_test)

# %%
# checking for class imbalances

df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# looking at accuracy
from sklearn.metrics import accuracy_score, confusion_matrix

accuracy_score(Y_predicted, Y_test)
# Out:
# 0.9473684210526315

# %%
# looking at confusion matrix
# y axis is the predictions, x is the actual

m = confusion_matrix(Y_predicted, Y_test)
sns.heatmap(m, annot = True)
# Out:
# <Axes: >

# %%
"""
The first columns is corrected, all class 0's are predicted correctly
The second column is mostly correct, 12/14 class 1 are correctly predicred as 1, but 2 of them are predicted as class 2
The third column is correct, the 6 that are of class 2 are predicted correctly
"""
# Out:
# "\nThe first columns is corrected, all class 0's are predicted correctly\nThe second column is mostly correct, 12/14 class 1 are correctly predicred as 1, but 2 of them are predicted as class 2\nThe third column is correct, the 6 that are of class 2 are predicted correctly\n"

# %%
### Logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
Y_predicted2 = model.predict(X_test)

# %%
accuracy_score(Y_predicted2, Y_test)
# Out:
# 0.9210526315789473

# %%
### Support Vector Machine (SVM)

# %%
# usually used for 2 classes, but can do mutilple classes
# by having multiple classifiers

# one vs one approach
# one vs many approach
